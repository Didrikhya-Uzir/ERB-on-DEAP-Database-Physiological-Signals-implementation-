MB 21.1 MB/s eta 0:00:00
# Installing collected packages: graphviz, catboost
# Successfully installed catboost-1.2.2 graphviz-0.20.1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
import catboost

# %%
feats_val = pd.read_csv('valence_features_200.csv', index_col=0)
feats_ar = pd.read_csv('arousal_features_200.csv', index_col=0)
feats_dom = pd.read_csv('dominance_features_200.csv', index_col=0)
feats_lik = pd.read_csv('liking_features_200.csv', index_col=0)

targets = pd.read_csv('za_klasifikaciju.csv', index_col=0)

# %%
targets = targets[['Valence', 'Arousal', 'Dominance', 'Liking']]
targets[targets < 4.5] = 0
targets[targets >= 4.5] = 1

# %%
targets.sample(15)
# Out:
#                 Valence  Arousal  Dominance  Liking
# Participant_id
# 27                  1.0      0.0        1.0     0.0
# 26                  1.0      1.0        1.0     1.0
# 30                  1.0      1.0        1.0     1.0
# 2                   1.0      1.0        1.0     1.0
# 13                  1.0      1.0        0.0     1.0
# 16                  0.0      1.0        0.0     1.0
# 11                  1.0      0.0        1.0     0.0
# 15                  1.0      1.0        1.0     1.0
# 22                  1.0      1.0        1.0     1.0
# 15                  1.0      0.0        1.0     1.0
# 10                  1.0      1.0        1.0     1.0
# 18                  0.0      0.0        1.0     0.0
# 2                   1.0      1.0        1.0     1.0
# 27                  1.0      1.0        1.0     1.0
# 18                  0.0      1.0        1.0     0.0

# %% [markdown]
# # Modeling

# %%
cat_params = {
    'loss_function':'Logloss',
    'eval_metric':'F1',
    'learning_rate':0.001,
    'depth':5,
    'subsample': 0.8
}

for c in ['Valence', 'Arousal', 'Dominance', 'Liking']:

    if c == 'Valence':
        data = feats_val
    elif c == 'Arousal':
        data = feats_ar
    elif c == 'Dominance':
        data = feats_dom
    elif c == 'Liking':
        data = feats_lik
    cat_crossval = catboost.Pool(data=data, label=targets[c])

    cat_cv = catboost.cv(pool=cat_crossval,
                        params=cat_params,
                        num_boost_round=5000,
                        nfold=10,
                        verbose_eval=0,
                        early_stopping_rounds=15
                        )
    ind_max = np.argmax(cat_cv['test-F1-mean'])
    print(f'{c}: test F1 mean = {cat_cv.loc[ind_max, "test-F1-mean"]}, std = {cat_cv.loc[ind_max, "test-F1-std"]}')
# Out:
# Training on fold [0/10]
#
# bestTest = 0.7788461538
# bestIteration = 3
#
# Training on fold [1/10]
#
# bestTest = 0.7766990291
# bestIteration = 1
#
# Training on fold [2/10]
#
# bestTest = 0.7788461538
# bestIteration = 4
#
# Training on fold [3/10]
#
# bestTest = 0.7788461538
# bestIteration = 2
#
# Training on fold [4/10]
#
# bestTest = 0.7788461538
# bestIteration = 2
#
# Training on fold [5/10]
#
# bestTest = 0.7826086957
# bestIteration = 2
#
# Training on fold [6/10]
#
# bestTest = 0.7751196172
# bestIteration = 4
#
# Training on fold [7/10]
#
# bestTest = 0.7826086957
# bestIteration = 1
#
# Training on fold [8/10]
#
# bestTest = 0.7804878049
# bestIteration = 3
#
# Training on fold [9/10]
#
# bestTest = 0.7729468599
# bestIteration = 2
#
# Valence: test F1 mean = 0.7743195102634461, std = 0.0022154696163690676
# Training on fold [0/10]
#
# bestTest = 0.7772511848
# bestIteration = 4
#
# Training on fold [1/10]
#
# bestTest = 0.7772511848
# bestIteration = 3
#
# Training on fold [2/10]
#
# bestTest = 0.7884615385
# bestIteration = 1
#
# Training on fold [3/10]
#
# bestTest = 0.780952381
# bestIteration = 5
#
# Training on fold [4/10]
#
# bestTest = 0.7846889952
# bestIteration = 0
#
# Training on fold [5/10]
#
# bestTest = 0.780952381
# bestIteration = 4
#
# Training on fold [6/10]
#
# bestTest = 0.780952381
# bestIteration = 9
#
# Training on fold [7/10]
#
# bestTest = 0.780952381
# bestIteration = 4
#
# Training on fold [8/10]
#
# bestTest = 0.7920792079
# bestIteration = 1
#
# Training on fold [9/10]
#
# bestTest = 0.7788461538
# bestIteration = 4
#
# Arousal: test F1 mean = 0.779790896307484, std = 0.0015909335084335135
# Training on fold [0/10]
#
# bestTest = 0.8037383178
# bestIteration = 0
#
# Training on fold [1/10]
#
# bestTest = 0.8
# bestIteration = 1
#
# Training on fold [2/10]
#
# bestTest = 0.8
# bestIteration = 1
#
# Training on fold [3/10]
#
# bestTest = 0.8037383178
# bestIteration = 0
#
# Training on fold [4/10]
#
# bestTest = 0.8113207547
# bestIteration = 1
#
# Training on fold [5/10]
#
# bestTest = 0.8075117371
# bestIteration = 1
#
# Training on fold [6/10]
#
# bestTest = 0.8018867925
# bestIteration = 3
#
# Training on fold [7/10]
#
# bestTest = 0.8018867925
# bestIteration = 1
#
# Training on fold [8/10]
#
# bestTest = 0.8018867925
# bestIteration = 3
#
# Training on fold [9/10]
#
# bestTest = 0.8056872038
# bestIteration = 2
#
# Dominance: test F1 mean = 0.8018824216663978, std = 0.001987157943993099
# Training on fold [0/10]
#
# bestTest = 0.8202764977
# bestIteration = 1
#
# Training on fold [1/10]
#
# bestTest = 0.8202764977
# bestIteration = 2
#
# Training on fold [2/10]
#
# bestTest = 0.8202764977
# bestIteration = 0
#
# Training on fold [3/10]
#
# bestTest = 0.8279069767
# bestIteration = 2
#
# Training on fold [4/10]
#
# bestTest = 0.8202764977
# bestIteration = 0
#
# Training on fold [5/10]
#
# bestTest = 0.8240740741
# bestIteration = 0
#
# Training on fold [6/10]
#
# bestTest = 0.8202764977
# bestIteration = 0
#
# Training on fold [7/10]
#
# bestTest = 0.8279069767
# bestIteration = 0
#
# Training on fold [8/10]
#
# bestTest = 0.8202764977
# bestIteration = 0
#
# Training on fold [9/10]
#
# bestTest = 0.8202764977
# bestIteration = 0
#
# Liking: test F1 mean = 0.8210360129714968, std = 0.0016011987924843668

# %%
cat_params = {
    'loss_function':'Logloss',
    'eval_metric':'Accuracy',
    'learning_rate':0.001,
    'depth':5,
    'subsample': 0.8
}

for c in ['Valence', 'Arousal', 'Dominance', 'Liking']:

    if c == 'Valence':
        data = feats_val
    elif c == 'Arousal':
        data = feats_ar
    elif c == 'Dominance':
        data = feats_dom
    elif c == 'Liking':
        data = feats_lik
    cat_crossval = catboost.Pool(data=data, label=targets[c])

    cat_cv = catboost.cv(pool=cat_crossval,
                        params=cat_params,
                        num_boost_round=5000,
                        nfold=10,
                        verbose_eval=0,
                        early_stopping_rounds=15
                        )
    ind_max = np.argmax(cat_cv['test-Accuracy-mean'])
    print(f'{c}: test Accuracy mean = {cat_cv.loc[ind_max, "test-Accuracy-mean"]}, std = {cat_cv.loc[ind_max, "test-Accuracy-std"]}')
# Out:
# Training on fold [0/10]
#
# bestTest = 0.6434108527
# bestIteration = 1
#
# Training on fold [1/10]
#
# bestTest = 0.6434108527
# bestIteration = 1
#
# Training on fold [2/10]
#
# bestTest = 0.640625
# bestIteration = 1
#
# Training on fold [3/10]
#
# bestTest = 0.640625
# bestIteration = 2
#
# Training on fold [4/10]
#
# bestTest = 0.640625
# bestIteration = 1
#
# Training on fold [5/10]
#
# bestTest = 0.6484375
# bestIteration = 2
#
# Training on fold [6/10]
#
# bestTest = 0.6328125
# bestIteration = 4
#
# Training on fold [7/10]
#
# bestTest = 0.6484375
# bestIteration = 1
#
# Training on fold [8/10]
#
# bestTest = 0.6456692913
# bestIteration = 3
#
# Training on fold [9/10]
#
# bestTest = 0.6299212598
# bestIteration = 0
#
# Valence: test Accuracy mean = 0.6335910318622963, std = 0.007689552917263559
# Training on fold [0/10]
#
# bestTest = 0.6356589147
# bestIteration = 4
#
# Training on fold [1/10]
#
# bestTest = 0.6356589147
# bestIteration = 3
#
# Training on fold [2/10]
#
# bestTest = 0.65625
# bestIteration = 1
#
# Training on fold [3/10]
#
# bestTest = 0.6484375
# bestIteration = 0
#
# Training on fold [4/10]
#
# bestTest = 0.6484375
# bestIteration = 0
#
# Training on fold [5/10]
#
# bestTest = 0.640625
# bestIteration = 4
#
# Training on fold [6/10]
#
# bestTest = 0.640625
# bestIteration = 9
#
# Training on fold [7/10]
#
# bestTest = 0.640625
# bestIteration = 4
#
# Training on fold [8/10]
#
# bestTest = 0.6692913386
# bestIteration = 1
#
# Training on fold [9/10]
#
# bestTest = 0.6377952756
# bestIteration = 1
#
# Arousal: test Accuracy mean = 0.6390719896386499, std = 0.0036468093453398045
# Training on fold [0/10]
#
# bestTest = 0.6744186047
# bestIteration = 0
#
# Training on fold [1/10]
#
# bestTest = 0.6666666667
# bestIteration = 1
#
# Training on fold [2/10]
#
# bestTest = 0.6666666667
# bestIteration = 1
#
# Training on fold [3/10]
#
# bestTest = 0.6744186047
# bestIteration = 0
#
# Training on fold [4/10]
#
# bestTest = 0.6875
# bestIteration = 1
#
# Training on fold [5/10]
#
# bestTest = 0.6796875
# bestIteration = 1
#
# Training on fold [6/10]
#
# bestTest = 0.6692913386
# bestIteration = 3
#
# Training on fold [7/10]
#
# bestTest = 0.6692913386
# bestIteration = 0
#
# Training on fold [8/10]
#
# bestTest = 0.6692913386
# bestIteration = 3
#
# Training on fold [9/10]
#
# bestTest = 0.6771653543
# bestIteration = 2
#
# Dominance: test Accuracy mean = 0.6695456036745405, std = 0.0033707869166371162
# Training on fold [0/10]
#
# bestTest = 0.6953125
# bestIteration = 1
#
# Training on fold [1/10]
#
# bestTest = 0.6953125
# bestIteration = 2
#
# Training on fold [2/10]
#
# bestTest = 0.6953125
# bestIteration = 0
#
# Training on fold [3/10]
#
# bestTest = 0.7109375
# bestIteration = 2
#
# Training on fold [4/10]
#
# bestTest = 0.6953125
# bestIteration = 0
#
# Training on fold [5/10]
#
# bestTest = 0.703125
# bestIteration = 0
#
# Training on fold [6/10]
#
# bestTest = 0.6953125
# bestIteration = 0
#
# Training on fold [7/10]
#
# bestTest = 0.7109375
# bestIteration = 0
#
# Training on fold [8/10]
#
# bestTest = 0.6953125
# bestIteration = 0
#
# Training on fold [9/10]
#
# bestTest = 0.6953125
# bestIteration = 0
#
# Liking: test Accuracy mean = 0.696875, std = 0.004941058844013091
